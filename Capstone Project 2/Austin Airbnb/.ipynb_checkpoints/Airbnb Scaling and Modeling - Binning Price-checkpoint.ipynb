# %%
# import libraries

from sklearn.model_selection import train_test_split
from sklearn.metrics import r2_score, mean_squared_error
from sklearn.preprocessing import MinMaxScaler, StandardScaler
from sklearn.neighbors import KNeighborsRegressor
from sklearn.linear_model import LinearRegression, LassoLarsCV
from sklearn.svm import SVR
from sklearn.ensemble import RandomForestRegressor
from sklearn.tree import DecisionTreeRegressor
import xgboost as xgb
from xgboost.sklearn import XGBRegressor
from sklearn.model_selection import GridSearchCV, cross_val_score, KFold
from scipy.stats import pearsonr
from sklearn.metrics import accuracy_score

import pandas as pd
import numpy as np

import time

# Pandas warning messages (optional)
pd.options.mode.chained_assignment = None  #default='warn'
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# Plot options
import matplotlib.pyplot as plt
import seaborn as sns
sns.palplot(sns.color_palette('deep'))
sns.set_style("whitegrid")
# %matplotlib inline

sns.set()

# I want crisp graphics, so we'll output SVG
# %config InlineBackend.figure_format = 'svg'

# %%
data = pd.read_csv('data/listings.csv', low_memory=False)

# %%
data.head()
# Out:
#      id                        listing_url       scrape_id last_scraped  \
# 0  2265  https://www.airbnb.com/rooms/2265  20200317143754   2020-03-17
# 1  5245  https://www.airbnb.com/rooms/5245  20200317143754   2020-03-17
# 2  5456  https://www.airbnb.com/rooms/5456  20200317143754   2020-03-17
# 3  5769  https://www.airbnb.com/rooms/5769  20200317143754   2020-03-17
# 4  6413  https://www.airbnb.com/rooms/6413  20200317143754   2020-03-17
#
#                                                 name  \
# 0   Zen-East in the Heart of Austin (monthly rental)
# 1  Eco friendly, Colorful, Clean, Cozy monthly share
# 2          Walk to 6th, Rainey St and Convention Ctr
# 3                                     NW Austin Room
# 4                      Gem of a Studio near Downtown
#
#                                              summary  \
# 0  Zen East is situated in a vibrant & diverse mu...
# 1  Situated in a vibrant & diverse multicultural ...
# 2  Great central  location for walking to Convent...
# 3                                                NaN
# 4  Great studio apartment, perfect for couples or...
#
#                                                space  \
# 0  This colorful and clean 1923 house was complet...
# 1  This green, colorful, clean and cozy house was...
# 2  Cute Private Studio apartment located in Willo...
# 3  Looking for a comfortable inexpensive room to ...
# 4  !!!!! SXSW info !!!!! Presently open (again!) ...
#
#                                          description experiences_offered  \
# 0  Zen East is situated in a vibrant & diverse mu...                none
# 1  Situated in a vibrant & diverse multicultural ...                none
# 2  Great central  location for walking to Convent...                none
# 3  Looking for a comfortable inexpensive room to ...                none
# 4  Great studio apartment, perfect for couples or...                none
#
#                                neighborhood_overview  \
# 0                                                NaN
# 1                                                NaN
# 2  My neighborhood is ideally located if you want...
# 3  Quiet neighborhood with lots of trees and good...
# 4  Travis Heights is one of the oldest neighborho...
#
#                                                notes  \
# 0  A 2013 Genuine Buddy Scooter 125 may be availa...
# 1  Please note: A two story studio was built in t...
# 2  Parking on street requires a permit.  Permits ...
# 3                                                NaN
# 4  Our calendar only extends a few months. If you...
#
#                                              transit  \
# 0  5 min walk to Capitol Metro Rail (train that t...
# 1                                                NaN
# 2  Bus stop around the block.  Uber, Lyft, Ride, ...
# 3  We are approximately 16 miles from downtown Au...
# 4  Parking for our place is on the street, roughl...
#
#                                               access  \
# 0  Several local restaurants, small clubs, music ...
# 1                                                NaN
# 2              Guests have access to yard and patio.
# 3                             Gravel Parking Kitchen
# 4     Private patio with lounge chairs and umbrella.
#
#                                          interaction  \
# 0  Depending on your dates and arrival time, I am...
# 1  I should be available, upon your arrival, to a...
# 2  I am happy to welcome my guests and show them in.
# 3  We interact with our guests as little or as mu...
# 4  You may see us during your stay, but you'll ma...
#
#                                          house_rules  thumbnail_url  \
# 0  • Check-in time is 4 pm. Check out is 11 am. I...            NaN
# 1  A brief profile for all guests along with phot...            NaN
# 2  No Pets allowed.  No smoking in the room. No m...            NaN
# 3  I will need to see identification at check in....            NaN
# 4  Posted prices include the 11% in local occupan...            NaN
#
#    medium_url                                        picture_url  \
# 0         NaN  https://a0.muscache.com/im/pictures/4740524/63...
# 1         NaN  https://a0.muscache.com/im/pictures/5167505/b3...
# 2         NaN  https://a0.muscache.com/im/pictures/14084884/b...
# 3         NaN  https://a0.muscache.com/im/pictures/23822033/a...
# 4         NaN  https://a0.muscache.com/im/pictures/349818/97e...
#
#    xl_picture_url  host_id                                 host_url  \
# 0             NaN     2466   https://www.airbnb.com/users/show/2466
# 1             NaN     2466   https://www.airbnb.com/users/show/2466
# 2             NaN     8028   https://www.airbnb.com/users/show/8028
# 3             NaN     8186   https://www.airbnb.com/users/show/8186
# 4             NaN    13879  https://www.airbnb.com/users/show/13879
#
#    host_name  host_since                 host_location  \
# 0      Paddy  2008-08-23  Austin, Texas, United States
# 1      Paddy  2008-08-23  Austin, Texas, United States
# 2     Sylvia  2009-02-16  Austin, Texas, United States
# 3  Elizabeth  2009-02-19  Austin, Texas, United States
# 4       Todd  2009-04-17  Austin, Texas, United States
#
#                                           host_about host_response_time  \
# 0  I am a long time resident of Austin. I earned ...                NaN
# 1  I am a long time resident of Austin. I earned ...                NaN
# 2  I am a licensed Real Estate Broker and owner o...     within an hour
# 3  We're easygoing professionals that enjoy meeti...                NaN
# 4  We're a young family that likes to travel, we ...     within an hour
#
#   host_response_rate host_acceptance_rate host_is_superhost  \
# 0                NaN                 100%                 t
# 1                NaN                 100%                 t
# 2               100%                  98%                 t
# 3                NaN                  92%                 t
# 4               100%                 100%                 t
#
#                                   host_thumbnail_url  \
# 0  https://a0.muscache.com/im/users/2466/profile_...
# 1  https://a0.muscache.com/im/users/2466/profile_...
# 2  https://a0.muscache.com/im/users/8028/profile_...
# 3  https://a0.muscache.com/im/users/8186/profile_...
# 4  https://a0.muscache.com/im/pictures/user/4f35e...
#
#                                     host_picture_url host_neighbourhood  \
# 0  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 1  https://a0.muscache.com/im/users/2466/profile_...      East Downtown
# 2  https://a0.muscache.com/im/users/8028/profile_...      East Downtown
# 3  https://a0.muscache.com/im/users/8186/profile_...  SW Williamson Co.
# 4  https://a0.muscache.com/im/pictures/user/4f35e...     Travis Heights
#
#    host_listings_count  host_total_listings_count  \
# 0                  3.0                        3.0
# 1                  3.0                        3.0
# 2                  1.0                        1.0
# 3                  1.0                        1.0
# 4                  1.0                        1.0
#
#                                   host_verifications host_has_profile_pic  \
# 0   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 1   ['email', 'phone', 'facebook', 'reviews', 'kba']                    t
# 2               ['email', 'phone', 'reviews', 'kba']                    t
# 3  ['email', 'phone', 'reviews', 'jumio', 'govern...                    t
# 4  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#   host_identity_verified                     street      neighbourhood  \
# 0                      t  Austin, TX, United States      East Downtown
# 1                      t  Austin, TX, United States      East Downtown
# 2                      t  Austin, TX, United States      East Downtown
# 3                      t  Austin, TX, United States  SW Williamson Co.
# 4                      f  Austin, TX, United States     Travis Heights
#
#    neighbourhood_cleansed  neighbourhood_group_cleansed    city state  \
# 0                   78702                           NaN  Austin    TX
# 1                   78702                           NaN  Austin    TX
# 2                   78702                           NaN  Austin    TX
# 3                   78729                           NaN  Austin    TX
# 4                   78704                           NaN  Austin    TX
#
#    zipcode  market smart_location country_code        country  latitude  \
# 0  78702.0  Austin     Austin, TX           US  United States  30.27750
# 1  78702.0  Austin     Austin, TX           US  United States  30.27577
# 2  78702.0  Austin     Austin, TX           US  United States  30.26112
# 3  78729.0  Austin     Austin, TX           US  United States  30.45697
# 4  78704.0  Austin     Austin, TX           US  United States  30.24829
#
#    longitude is_location_exact property_type        room_type  accommodates  \
# 0  -97.71398                 f         House  Entire home/apt             4
# 1  -97.71379                 t         House     Private room             2
# 2  -97.73448                 t    Guesthouse  Entire home/apt             3
# 3  -97.78422                 t         House     Private room             2
# 4  -97.73726                 t    Guesthouse  Entire home/apt             2
#
#    bathrooms  bedrooms  beds  bed_type  \
# 0        2.0       2.0   2.0  Real Bed
# 1        1.0       1.0   2.0  Real Bed
# 2        1.0       1.0   2.0  Real Bed
# 3        1.0       1.0   1.0  Real Bed
# 4        1.0       0.0   1.0  Real Bed
#
#                                            amenities  square_feet    price  \
# 0  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $225.00
# 1  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN  $100.00
# 2  {TV,Wifi,"Air conditioning",Kitchen,"Pets live...          NaN   $95.00
# 3  {TV,"Cable TV",Internet,Wifi,"Air conditioning...          NaN   $40.00
# 4  {TV,"Cable TV",Internet,Wifi,"Air conditioning...        550.0   $99.00
#
#   weekly_price monthly_price security_deposit cleaning_fee  guests_included  \
# 0          NaN           NaN          $500.00      $100.00                4
# 1          NaN           NaN          $500.00       $75.00                2
# 2          NaN           NaN          $100.00          NaN                2
# 3      $160.00           NaN              NaN          NaN                2
# 4      $700.00     $1,900.00              NaN       $50.00                2
#
#   extra_people  minimum_nights  maximum_nights  minimum_minimum_nights  \
# 0       $30.00              30              90                      30
# 1       $35.00              30              60                      30
# 2       $45.00               2              90                       2
# 3        $0.00               1              14                       1
# 4       $25.00               3             365                       3
#
#    maximum_minimum_nights  minimum_maximum_nights  maximum_maximum_nights  \
# 0                      30                      90                      90
# 1                      30                      60                      60
# 2                       2                      90                      90
# 3                       1                      14                      14
# 4                       3                    1125                    1125
#
#    minimum_nights_avg_ntm  maximum_nights_avg_ntm calendar_updated  \
# 0                    30.0                    90.0     7 months ago
# 1                    30.0                    60.0     9 months ago
# 2                     2.0                    90.0       6 days ago
# 3                     1.0                    14.0      7 weeks ago
# 4                     3.0                  1125.0        yesterday
#
#   has_availability  availability_30  availability_60  availability_90  \
# 0                t                0                0                0
# 1                t                0                0                0
# 2                t               23               46               70
# 3                t                0                0               14
# 4                t                0                0                0
#
#    availability_365 calendar_last_scraped  number_of_reviews  \
# 0                 0            2020-03-17                 24
# 1                 0            2020-03-17                  9
# 2               334            2020-03-17                529
# 3                14            2020-03-17                257
# 4                 0            2020-03-17                112
#
#    number_of_reviews_ltm first_review last_review  review_scores_rating  \
# 0                      0   2009-03-17  2019-03-16                  93.0
# 1                      0   2009-03-19  2018-03-14                  91.0
# 2                     53   2009-03-08  2020-03-01                  97.0
# 3                     16   2010-04-10  2019-11-03                  98.0
# 4                     23   2009-12-14  2020-03-08                  99.0
#
#    review_scores_accuracy  review_scores_cleanliness  review_scores_checkin  \
# 0                     9.0                       10.0                   10.0
# 1                    10.0                        8.0                   10.0
# 2                    10.0                       10.0                   10.0
# 3                    10.0                       10.0                   10.0
# 4                    10.0                       10.0                   10.0
#
#    review_scores_communication  review_scores_location  review_scores_value  \
# 0                         10.0                     8.0                  9.0
# 1                          9.0                    10.0                  9.0
# 2                         10.0                    10.0                 10.0
# 3                         10.0                    10.0                 10.0
# 4                         10.0                    10.0                 10.0
#
#   requires_license      license jurisdiction_names instant_bookable  \
# 0                f          NaN    {"Texas State"}                f
# 1                f          NaN    {"Texas State"}                f
# 2                f          NaN    {"Texas State"}                f
# 3                f          NaN    {"Texas State"}                f
# 4                f  32041657928    {"Texas State"}                t
#
#   is_business_travel_ready          cancellation_policy  \
# 0                        f  strict_14_with_grace_period
# 1                        f  strict_14_with_grace_period
# 2                        f  strict_14_with_grace_period
# 3                        f                     moderate
# 4                        f  strict_14_with_grace_period
#
#   require_guest_profile_picture require_guest_phone_verification  \
# 0                             f                                f
# 1                             f                                f
# 2                             f                                t
# 3                             t                                t
# 4                             f                                f
#
#    calculated_host_listings_count  \
# 0                               3
# 1                               3
# 2                               1
# 3                               1
# 4                               1
#
#    calculated_host_listings_count_entire_homes  \
# 0                                            2
# 1                                            2
# 2                                            1
# 3                                            0
# 4                                            1
#
#    calculated_host_listings_count_private_rooms  \
# 0                                             1
# 1                                             1
# 2                                             0
# 3                                             1
# 4                                             0
#
#    calculated_host_listings_count_shared_rooms  reviews_per_month
# 0                                            0               0.18
# 1                                            0               0.07
# 2                                            0               3.94
# 3                                            0               2.12
# 4                                            0               0.90

# %%
data.isna().sum().sort_values(ascending=False)[:38].index
# Out:
# Index(['neighbourhood_group_cleansed', 'thumbnail_url', 'medium_url',
#        'xl_picture_url', 'license', 'square_feet', 'monthly_price',
#        'weekly_price', 'notes', 'access', 'transit', 'host_about',
#        'interaction', 'house_rules', 'neighborhood_overview',
#        'host_response_rate', 'host_response_time', 'security_deposit',
#        'host_acceptance_rate', 'review_scores_location', 'review_scores_value',
#        'review_scores_communication', 'review_scores_checkin',
#        'review_scores_cleanliness', 'review_scores_accuracy',
#        'review_scores_rating', 'space', 'host_neighbourhood', 'first_review',
#        'last_review', 'reviews_per_month', 'cleaning_fee', 'neighbourhood',
#        'summary', 'description', 'zipcode', 'beds', 'host_location'],
#       dtype='object')

# %%
data.drop(['neighbourhood_group_cleansed', 'thumbnail_url', 'medium_url',
       'xl_picture_url', 'license', 'square_feet', 'monthly_price',
       'weekly_price', 'notes', 'access', 'transit', 'host_about',
       'interaction', 'house_rules', 'neighborhood_overview',
       'host_response_rate', 'host_response_time', 'security_deposit',
       'host_acceptance_rate', 'review_scores_location', 'review_scores_value',
       'review_scores_communication', 'review_scores_checkin',
       'review_scores_cleanliness', 'review_scores_accuracy',
       'review_scores_rating', 'space', 'host_neighbourhood', 'first_review',
       'last_review', 'reviews_per_month', 'cleaning_fee', 'neighbourhood',
       'summary', 'description', 'zipcode', 'beds', 'host_location'], axis=1, inplace=True)

# %%
top14na_cols = data.isna().sum().sort_values(ascending=False)[:14].index
top14na_cols
# Out:
# Index(['bedrooms', 'bathrooms', 'market', 'state', 'host_since',
#        'host_identity_verified', 'host_total_listings_count',
#        'host_listings_count', 'host_picture_url', 'host_thumbnail_url', 'city',
#        'host_has_profile_pic', 'host_name', 'host_is_superhost'],
#       dtype='object')

# %%
data.groupby('property_type')['bedrooms'].describe()
# Out:
#                      count      mean       std  min   25%  50%   75%   max
# property_type
# Aparthotel            24.0  2.916667  4.871538  1.0  1.00  1.0  2.00  23.0
# Apartment           3102.0  1.238233  0.674056  0.0  1.00  1.0  2.00   5.0
# Barn                   4.0  1.750000  1.500000  1.0  1.00  1.0  1.75   4.0
# Bed and breakfast     31.0  1.483871  1.287659  1.0  1.00  1.0  2.00   8.0
# Boat                   6.0  2.500000  0.836660  1.0  2.25  3.0  3.00   3.0
# Boutique hotel        39.0  1.000000  0.688247  0.0  1.00  1.0  1.00   4.0
# Bungalow             297.0  1.885522  0.941010  0.0  1.00  2.0  2.00   7.0
# Bus                    2.0  2.000000  1.414214  1.0  1.50  2.0  2.50   3.0
# Cabin                 18.0  1.388889  0.916444  0.0  1.00  1.0  1.75   4.0
# Camper/RV             90.0  0.900000  0.983573  0.0  0.00  1.0  1.00   7.0
# Campsite               9.0  2.555556  4.245913  0.0  0.00  1.0  1.00  10.0
# Chalet                 2.0  2.500000  0.707107  2.0  2.25  2.5  2.75   3.0
# Condominium         1064.0  1.532895  0.994268  0.0  1.00  1.0  2.00   9.0
# Cottage               68.0  1.455882  0.761652  0.0  1.00  1.0  2.00   4.0
# Dome house             3.0  3.666667  1.154701  3.0  3.00  3.0  4.00   5.0
# Earth house            1.0  1.000000       NaN  1.0  1.00  1.0  1.00   1.0
# Farm stay              9.0  1.777778  1.481366  0.0  1.00  1.0  2.00   5.0
# Guest suite          271.0  0.944649  0.577894  0.0  1.00  1.0  1.00   2.0
# Guesthouse           537.0  0.890130  0.661463  0.0  0.00  1.0  1.00   4.0
# Hostel                25.0  0.920000  0.276887  0.0  1.00  1.0  1.00   1.0
# Hotel                  4.0  1.750000  0.500000  1.0  1.75  2.0  2.00   2.0
# House               5104.0  2.336991  1.399615  0.0  1.00  2.0  3.00  14.0
# Houseboat              3.0  2.666667  1.154701  2.0  2.00  2.0  3.00   4.0
# Loft                 137.0  1.343066  0.861240  0.0  1.00  1.0  2.00   4.0
# Nature lodge           1.0  2.000000       NaN  2.0  2.00  2.0  2.00   2.0
# Other                 39.0  1.256410  0.992550  0.0  1.00  1.0  1.00   6.0
# Resort                48.0  1.500000  0.618853  0.0  1.00  2.0  2.00   3.0
# Serviced apartment   166.0  1.325301  0.986066  0.0  1.00  1.0  2.00   5.0
# Tent                  12.0  1.250000  1.864745  0.0  0.75  1.0  1.00   7.0
# Tiny house            64.0  0.859375  0.709733  0.0  0.00  1.0  1.00   4.0
# Tipi                   3.0  0.000000  0.000000  0.0  0.00  0.0  0.00   0.0
# Townhouse            417.0  1.995204  1.130851  1.0  1.00  2.0  3.00  15.0
# Treehouse              5.0  1.200000  0.836660  0.0  1.00  1.0  2.00   2.0
# Villa                 44.0  4.659091  1.569227  1.0  4.00  5.0  5.00   9.0
# Yurt                   4.0  0.750000  0.500000  0.0  0.75  1.0  1.00   1.0

# %%
data.loc[(data['bedrooms'] == 23)]
# Out:
#             id                            listing_url       scrape_id  \
# 6819  28466259  https://www.airbnb.com/rooms/28466259  20200317143754
#
#      last_scraped                                               name  \
# 6819   2020-03-17  Entire Hotel on 6th St: 5 Suites / 23 BR / 61 ...
#
#      experiences_offered                                        picture_url  \
# 6819                none  https://a0.muscache.com/im/pictures/cddcd33e-a...
#
#       host_id                                  host_url host_name  host_since  \
# 6819   814883  https://www.airbnb.com/users/show/814883   Kristen  2011-07-13
#
#      host_is_superhost                                 host_thumbnail_url  \
# 6819                 t  https://a0.muscache.com/im/users/814883/profil...
#
#                                        host_picture_url  host_listings_count  \
# 6819  https://a0.muscache.com/im/users/814883/profil...                 12.0
#
#       host_total_listings_count  \
# 6819                       12.0
#
#                                      host_verifications host_has_profile_pic  \
# 6819  ['email', 'phone', 'reviews', 'jumio', 'offlin...                    t
#
#      host_identity_verified                     street  \
# 6819                      f  Austin, TX, United States
#
#       neighbourhood_cleansed    city state  market smart_location  \
# 6819                   78702  Austin    TX  Austin     Austin, TX
#
#      country_code        country  latitude  longitude is_location_exact  \
# 6819           US  United States  30.26488  -97.73018                 t
#
#      property_type   room_type  accommodates  bathrooms  bedrooms  bed_type  \
# 6819    Aparthotel  Hotel room            16       17.0      23.0  Real Bed
#
#                                               amenities      price  \
# 6819  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...  $3,875.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 6819               16       $25.00               2             365
#
#       minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 6819                       1                       2                     365
#
#       maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 6819                     365                     1.3                   365.0
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 6819            today                t                7               12
#
#       availability_90  availability_365 calendar_last_scraped  \
# 6819               21               219            2020-03-17
#
#       number_of_reviews  number_of_reviews_ltm requires_license  \
# 6819                  0                      0                f
#
#      jurisdiction_names instant_bookable is_business_travel_ready  \
# 6819    {"Texas State"}                t                        f
#
#               cancellation_policy require_guest_profile_picture  \
# 6819  strict_14_with_grace_period                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 6819                                f                              12
#
#       calculated_host_listings_count_entire_homes  \
# 6819                                            6
#
#       calculated_host_listings_count_private_rooms  \
# 6819                                             0
#
#       calculated_host_listings_count_shared_rooms
# 6819                                            0

# %%
data = data.loc[data['bedrooms'] < 5]

# %%
data.groupby('property_type')['bedrooms'].describe()
# Out:
#                      count      mean       std  min   25%  50%   75%  max
# property_type
# Aparthotel            20.0  1.200000  0.410391  1.0  1.00  1.0  1.00  2.0
# Apartment           3100.0  1.235806  0.667463  0.0  1.00  1.0  2.00  4.0
# Barn                   4.0  1.750000  1.500000  1.0  1.00  1.0  1.75  4.0
# Bed and breakfast     30.0  1.266667  0.449776  1.0  1.00  1.0  1.75  2.0
# Boat                   6.0  2.500000  0.836660  1.0  2.25  3.0  3.00  3.0
# Boutique hotel        39.0  1.000000  0.688247  0.0  1.00  1.0  1.00  4.0
# Bungalow             295.0  1.854237  0.862547  0.0  1.00  2.0  2.00  4.0
# Bus                    2.0  2.000000  1.414214  1.0  1.50  2.0  2.50  3.0
# Cabin                 18.0  1.388889  0.916444  0.0  1.00  1.0  1.75  4.0
# Camper/RV             88.0  0.784091  0.595942  0.0  0.00  1.0  1.00  3.0
# Campsite               7.0  0.428571  0.534522  0.0  0.00  0.0  1.00  1.0
# Chalet                 2.0  2.500000  0.707107  2.0  2.25  2.5  2.75  3.0
# Condominium         1050.0  1.468571  0.815404  0.0  1.00  1.0  2.00  4.0
# Cottage               68.0  1.455882  0.761652  0.0  1.00  1.0  2.00  4.0
# Dome house             2.0  3.000000  0.000000  3.0  3.00  3.0  3.00  3.0
# Earth house            1.0  1.000000       NaN  1.0  1.00  1.0  1.00  1.0
# Farm stay              8.0  1.375000  0.916125  0.0  1.00  1.0  2.00  3.0
# Guest suite          271.0  0.944649  0.577894  0.0  1.00  1.0  1.00  2.0
# Guesthouse           537.0  0.890130  0.661463  0.0  0.00  1.0  1.00  4.0
# Hostel                25.0  0.920000  0.276887  0.0  1.00  1.0  1.00  1.0
# Hotel                  4.0  1.750000  0.500000  1.0  1.75  2.0  2.00  2.0
# House               4774.0  2.107248  1.083860  0.0  1.00  2.0  3.00  4.0
# Houseboat              3.0  2.666667  1.154701  2.0  2.00  2.0  3.00  4.0
# Loft                 137.0  1.343066  0.861240  0.0  1.00  1.0  2.00  4.0
# Nature lodge           1.0  2.000000       NaN  2.0  2.00  2.0  2.00  2.0
# Other                 38.0  1.131579  0.622595  0.0  1.00  1.0  1.00  3.0
# Resort                48.0  1.500000  0.618853  0.0  1.00  2.0  2.00  3.0
# Serviced apartment   165.0  1.303030  0.946265  0.0  1.00  1.0  2.00  4.0
# Tent                  11.0  0.727273  0.467099  0.0  0.50  1.0  1.00  1.0
# Tiny house            64.0  0.859375  0.709733  0.0  0.00  1.0  1.00  4.0
# Tipi                   3.0  0.000000  0.000000  0.0  0.00  0.0  0.00  0.0
# Townhouse            409.0  1.909535  0.842575  1.0  1.00  2.0  3.00  4.0
# Treehouse              5.0  1.200000  0.836660  0.0  1.00  1.0  2.00  2.0
# Villa                 20.0  3.400000  0.994723  1.0  3.00  4.0  4.00  4.0
# Yurt                   4.0  0.750000  0.500000  0.0  0.75  1.0  1.00  1.0

# %%
sns.countplot(data['bedrooms'])

# %%
len(data[data['bedrooms'] == 0])
# Out:
# 716

# %%
data.groupby(data['accommodates'])['bedrooms'].median()
# Out:
# accommodates
# 1     1.0
# 2     1.0
# 3     1.0
# 4     1.0
# 5     2.0
# 6     2.0
# 7     3.0
# 8     3.0
# 9     3.0
# 10    4.0
# 11    4.0
# 12    4.0
# 13    3.0
# 14    3.5
# 15    4.0
# 16    3.0
# Name: bedrooms, dtype: float64

# %%
data['bedrooms'].replace(0, np.nan, inplace=True)
data['bedrooms'].fillna(data.groupby(data['accommodates'])['bedrooms'].median(), inplace=True)
data['bedrooms'].value_counts()
# Out:
# 1.0    5527
# 2.0    2734
# 3.0    1591
# 4.0     692
# Name: bedrooms, dtype: int64

# %%
sns.countplot(data['bedrooms'])

# %%
data.groupby('property_type')['bathrooms'].describe()
# Out:
#                      count      mean       std  min    25%   50%    75%  max
# property_type
# Aparthotel            20.0  1.550000  1.087005  1.0  1.000  1.00  2.000  4.5
# Apartment           3097.0  1.218114  0.436510  0.0  1.000  1.00  1.000  4.0
# Barn                   4.0  1.250000  0.500000  1.0  1.000  1.00  1.250  2.0
# Bed and breakfast     30.0  1.066667  0.365148  0.0  1.000  1.00  1.000  2.0
# Boat                   6.0  1.750000  0.758288  1.0  1.125  1.75  2.000  3.0
# Boutique hotel        39.0  1.153846  0.514958  1.0  1.000  1.00  1.000  4.0
# Bungalow             295.0  1.281356  0.477905  0.0  1.000  1.00  1.500  3.0
# Bus                    2.0  1.000000  0.000000  1.0  1.000  1.00  1.000  1.0
# Cabin                 18.0  1.194444  0.667279  0.0  1.000  1.00  1.000  3.0
# Camper/RV             88.0  1.000000  0.283654  0.0  1.000  1.00  1.000  2.0
# Campsite               7.0  0.857143  0.377964  0.0  1.000  1.00  1.000  1.0
# Chalet                 2.0  2.500000  1.414214  1.5  2.000  2.50  3.000  3.5
# Condominium         1050.0  1.396190  0.586376  1.0  1.000  1.00  2.000  4.0
# Cottage               68.0  1.191176  0.539689  1.0  1.000  1.00  1.000  4.0
# Dome house             2.0  1.500000  0.000000  1.5  1.500  1.50  1.500  1.5
# Earth house            1.0  1.000000       NaN  1.0  1.000  1.00  1.000  1.0
# Farm stay              8.0  1.187500  0.651235  0.0  1.000  1.00  1.625  2.0
# Guest suite          271.0  1.036900  0.178792  0.5  1.000  1.00  1.000  2.0
# Guesthouse           537.0  1.071695  0.289717  1.0  1.000  1.00  1.000  4.5
# Hostel                25.0  2.160000  1.662829  0.0  1.000  1.00  4.500  4.5
# Hotel                  4.0  1.750000  0.500000  1.0  1.750  2.00  2.000  2.0
# House               4764.0  1.687552  0.778500  0.0  1.000  1.50  2.000  6.0
# Houseboat              3.0  1.833333  0.288675  1.5  1.750  2.00  2.000  2.0
# Loft                 137.0  1.211679  0.456661  0.0  1.000  1.00  1.500  3.0
# Nature lodge           1.0  1.500000       NaN  1.5  1.500  1.50  1.500  1.5
# Other                 38.0  1.263158  0.566364  0.0  1.000  1.00  1.500  2.5
# Resort                48.0  1.572917  0.574175  1.0  1.000  2.00  2.000  3.0
# Serviced apartment   165.0  1.466667  0.555278  1.0  1.000  1.00  2.000  3.5
# Tent                  11.0  1.000000  0.000000  1.0  1.000  1.00  1.000  1.0
# Tiny house            64.0  0.929688  0.365878  0.0  1.000  1.00  1.000  2.0
# Tipi                   3.0  0.000000  0.000000  0.0  0.000  0.00  0.000  0.0
# Townhouse            409.0  1.837408  0.762860  1.0  1.000  1.50  2.500  4.5
# Treehouse              5.0  1.400000  0.547723  1.0  1.000  1.00  2.000  2.0
# Villa                 20.0  3.125000  1.179596  1.0  2.500  3.25  4.000  5.5
# Yurt                   4.0  0.750000  0.500000  0.0  0.750  1.00  1.000  1.0

# %%
data[data['bathrooms'] == 6]
# Out:
#             id                            listing_url       scrape_id  \
# 4225  18970880  https://www.airbnb.com/rooms/18970880  20200317143754
#
#      last_scraped                                       name  \
# 4225   2020-03-17  Luxury Modern Estate Home in Barton Creek
#
#      experiences_offered                                        picture_url  \
# 4225                none  https://a0.muscache.com/im/pictures/75c35a2a-b...
#
#       host_id                                   host_url  host_name  \
# 4225  2947621  https://www.airbnb.com/users/show/2947621  Krisstina
#
#       host_since host_is_superhost  \
# 4225  2012-07-15                 t
#
#                                      host_thumbnail_url  \
# 4225  https://a0.muscache.com/im/pictures/user/98257...
#
#                                        host_picture_url  host_listings_count  \
# 4225  https://a0.muscache.com/im/pictures/user/98257...                  2.0
#
#       host_total_listings_count  \
# 4225                        2.0
#
#                                      host_verifications host_has_profile_pic  \
# 4225  ['email', 'phone', 'facebook', 'reviews', 'jum...                    t
#
#      host_identity_verified                     street  \
# 4225                      t  Austin, TX, United States
#
#       neighbourhood_cleansed    city state  market smart_location  \
# 4225                   78735  Austin    TX  Austin     Austin, TX
#
#      country_code        country  latitude  longitude is_location_exact  \
# 4225           US  United States   30.2791  -97.86459                 t
#
#      property_type        room_type  accommodates  bathrooms  bedrooms  \
# 4225         House  Entire home/apt             8        6.0       4.0
#
#       bed_type                                          amenities      price  \
# 4225  Real Bed  {TV,Wifi,"Air conditioning",Pool,Kitchen,"Free...  $1,950.00
#
#       guests_included extra_people  minimum_nights  maximum_nights  \
# 4225                8      $125.00               2              90
#
#       minimum_minimum_nights  maximum_minimum_nights  minimum_maximum_nights  \
# 4225                       2                       2                      90
#
#       maximum_maximum_nights  minimum_nights_avg_ntm  maximum_nights_avg_ntm  \
# 4225                      90                     2.0                    90.0
#
#      calendar_updated has_availability  availability_30  availability_60  \
# 4225     2 months ago                t                0                0
#
#       availability_90  availability_365 calendar_last_scraped  \
# 4225                0                 0            2020-03-17
#
#       number_of_reviews  number_of_reviews_ltm requires_license  \
# 4225                 14                      7                f
#
#      jurisdiction_names instant_bookable is_business_travel_ready  \
# 4225    {"Texas State"}                t                        f
#
#      cancellation_policy require_guest_profile_picture  \
# 4225            moderate                             f
#
#      require_guest_phone_verification  calculated_host_listings_count  \
# 4225                                f                               3
#
#       calculated_host_listings_count_entire_homes  \
# 4225                                            3
#
#       calculated_host_listings_count_private_rooms  \
# 4225                                             0
#
#       calculated_host_listings_count_shared_rooms
# 4225                                            0

# %%
data['bathrooms'].replace(0, np.nan, inplace=True)
data['bathrooms'].fillna(data.groupby(data['accommodates'])['bathrooms'].median(), inplace=True)
data['bathrooms'].value_counts()
# Out:
# 1.0    6849
# 2.0    2246
# 1.5     760
# 2.5     753
# 3.0     340
# 3.5     141
# 4.0      69
# 4.5      32
# 0.5      14
# 5.5       4
# 5.0       3
# 6.0       1
# Name: bathrooms, dtype: int64
