# %% [markdown]
# ## Python statistics essential training - 05_06_bayesian

# %% [markdown]
# Standard imports

# %%
import math

# %%
import numpy as np
import pandas as pd

# %%
import matplotlib
import matplotlib.pyplot as pp

# %%
# %matplotlib inline

# %%
import pymc3 as pm
# Out:
# C:\Users\rtalebiz\AppData\Local\Continuum\anaconda3\lib\site-packages\distributed\config.py:20: YAMLLoadWarning: calling yaml.load() without Loader=... is deprecated, as the default Loader is unsafe. Please read https://msg.pyyaml.org/load for full details.
#   defaults = yaml.load(f)

# %%
n= 100
k = 61

with pm.Model() as coin_context:
    p = pm.Uniform('p', 0.40, 0.80)
    
    y = pm.Binomial('y', n=n, p=p, observed=k)
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [p]
# Sampling 4 chains: 100%|████████████████████████████████████████████████████| 42000/42000 [00:20<00:00, 2045.69draws/s]

# %%
pm.summary(trace)
# Out:
#       mean        sd  mc_error   hpd_2.5  hpd_97.5        n_eff      Rhat
# p  0.60759  0.048187  0.000392  0.513653  0.701942  14807.83296  1.000243

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B3965B3780>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B396641278>]],
#       dtype=object)

# %%
gdata=pd.read_csv('gapminder.csv').query('year == 1985')

# %%
gdata.sort_values('age5_surviving', inplace=True)

# %%
pp.scatter(gdata['age5_surviving'], gdata['babies_per_woman'])

# %%
with pm.Model() as gapminder_context:
    intercept = pm.Uniform('intercept', 5, 15)
    
    slope = pm.Uniform('slope', -1, 1)
    
    babies = pm.Normal('babies', 
                       mu = intercept + slope * (gdata['age5_surviving'] - 65),
                       sd = 1, 
                       observed = gdata['babies_per_woman'])
    
    trace = pm.sample(10000)
# Out:
# Auto-assigning NUTS sampler...
# Initializing NUTS using jitter+adapt_diag...
# Multiprocess sampling (4 chains in 4 jobs)
# NUTS: [slope, intercept]
# Sampling 4 chains: 100%|████████████████████████████████████████████████████| 42000/42000 [00:38<00:00, 1102.48draws/s]
# The acceptance probability does not match the target. It is 0.904627210115354, but should be close to 0.8. Try to increase the number of tuning steps.
# The number of effective samples is smaller than 25% for some parameters.

# %%
pm.summary(trace)
# Out:
#                 mean        sd  mc_error   hpd_2.5   hpd_97.5        n_eff  \
# intercept  10.198097  0.282598  0.003021  9.640525  10.754290  9181.287122
# slope      -0.219386  0.010214  0.000112 -0.239563  -0.199338  9173.753794
#
#                Rhat
# intercept  1.000225
# slope      1.000211

# %%
pm.traceplot(trace)
# Out:
# array([[<matplotlib.axes._subplots.AxesSubplot object at 0x000001B39BB56BA8>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B39BB65CC0>],
#        [<matplotlib.axes._subplots.AxesSubplot object at 0x000001B39BB78E10>,
#         <matplotlib.axes._subplots.AxesSubplot object at 0x000001B39BB8AB38>]],
#       dtype=object)

# %%
babies = trace['intercept'].mean() + trace['slope'].mean() * (gdata['age5_surviving'] - 65)

# %%
pp.scatter(gdata['age5_surviving'], gdata['babies_per_woman'])
pp.plot(gdata['age5_surviving'], babies, 'C1')

# %%
pp.scatter(gdata['age5_surviving'], gdata['babies_per_woman'])

for i, intercept, slope in zip(range(100), trace['intercept'][::50], trace['slope'][::50]):
    babies = intercept + slope * (gdata['age5_surviving'] - 65)
    pp.plot(gdata['age5_surviving'], babies, 'C1', alpha=0.05)
